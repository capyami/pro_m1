# %% [markdown]
# ## Adquisition db bicimad

# %%
# libraries

# %%
import duckdb
import pandas as pd

# %%
datab = duckdb.connect('bicimad.db')
datab

# %%
# 11 filas
dfbps = datab.sql('select * from bicipark_stations').df()
dfbps
# Out:
#     stationId                 stationName                           address
# 0          74  Bicipark Fuente de la Mora     Estación de Fuente de la Mora  \
# 1          22             Bicipark Orense         Avenida General Perón, 27
# 2          49          Bicipark Montalban             Calle de Montalbán, 5
# 3          12            Bicipark Almagro                 Calle Almagro, 11
# 4           9          Bicipark Recoletos             Paseo de Recoletos, 2
# 5           5           Bicipark Recuerdo                  Calle Hiedra, 26
# 6          25          Bicipark Salamanca      Pl. del Marqués de Salamanca
# 7          67     Bicipark Villa de Paris         Calle de Orellana, 23, 21
# 8        1154              Bicipark Pitis  Calle Pau Arroyo del Fresno, 181
# 9        1169           Bicipark Aviación         Parking Aviación Española
# 10       1238          Bicipark Canalejas                                 -
#
# ...

# %%
df = datab.sql('select * from bicipark_stations join bicimad_stations on bicipark_stations.address = bicimad_stations.address').df()
df
# Out:
# Empty DataFrame
# Columns: [stationId, stationName, address, city, zip_code, total_places, free_places, enabled, reserved_places, geometry.type, geometry.coordinates, id, name, light, number, address_2, activate, no_available, total_bases, dock_bikes, free_bases, reservations_count, geometry.type_2, geometry.coordinates_2]
# Index: []
#
# [0 rows x 24 columns]

# %%
# 264 filas
dfbms = datab.sql('select * from bicimad_stations').df()
dfbms
# Out:
#       id                          name  light number
# 0      1         1a - Puerta del Sol A      3     1a  \
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate
# 0                                  Puerta del Sol nº 1         1  \
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# ...
